# %% [markdown]
# # Data Cleaning

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
pd.set_option('display.max_columns', None) #show all columns
import numpy as np

csv = ("individual-finance-v2.csv")
df = pd.read_csv(csv)
df.head(3)
# Out:
#   PostCode Gender  Age              Demographics  \
# 0   M5A3Z2      M  65+    65 years and over-Male
# 1   M5A3Z2      F  65+  65 years and over-Female
# 2   M5A3Z2      F  65+  65 years and over-Female
#
#                                           Ethnicity                  Religion  \
# 0                             British Isles origins                 Christian
# 1                                           Chinese  No religious affiliation
# 2  Western European origins (except French origins)                 Christian
#
#                                          Immigration  \
# 0  Immigrants. An immigrant refers to a person wh...
# 1  Immigrants. An immigrant refers to a person wh...
# 2  Non-immigrants. Refer to persons who are Canad...
#
#                                            Education  \
# 0                                  Bachelor's degree
# 1  Secondary (high) school diploma or equivalency...
# 2                  No certificate, diploma or degree
#
#                                    Field.of.Study  \
# 0         Social and behavioural sciences and law
# 1  Mathematics, computer and information sciences
# 2                                       Education
#
#                                           Profession Marital.Status  \
# 0                                 44-45 Retail trade        Married
# 1                           52 Finance and insurance        Widowed
# 2  54 Professional, scientific and technical serv...        Married
#
#   Family.Size                                           Dwelling  \
# 0   2 persons  Single-detached house: A single dwelling not a...
# 1   3 persons                            Other attached dwelling
# 2   2 persons                            Other attached dwelling
#
#       Personal.Income                                       credit_card  \
# 0   $150,000 and over   Percent Household Having Credit Cards: 5+ Cards
# 1  $40,000 to $49,999  Percent Household Having Credit Cards: 3-4 Cards
# 2  $10,000 to $19,999  Percent Household Having Credit Cards: 1-2 Cards
#
#                                          pay_balance  \
# 0  Percent Household Usually Do Not Pay Off Balan...
# 1  Percent Household Usually Do Not Pay Off Balan...
# 2  Percent Household Usually Do Not Pay Off Balan...
#
#                                            refuse_cc  \
# 0  Percent Household in Which Someone Was Refused...
# 1  Percent Household in Which Someone Was Refused...
# 2  Percent Household in Which Someone Was Refused...
#
#                                             mortgage  \
# 0  Percent Homeowner without Mortgage Among All H...
# 1  Percent Homeowner without Mortgage Among All H...
# 2  Percent Homeowner with Mortgage  Among All Hou...
#
#                                  budget  \
# 0  Percent Household that Has No Budget
# 1     Percent Household that Has Budget
# 2     Percent Household that Has Budget
#
#                                       unexpected_500  \
# 0  Percent Household who Would Finance an Unexpec...
# 1  Percent Household who Would Finance an Unexpec...
# 2  Percent Household who Would Finance an Unexpec...
#
#                                      unexpected_5000  \
# 0  Percent Household who Would Finance an Unexpec...
# 1  Percent Household who Would Finance an Unexpec...
# 2  Percent Household who Would Finance an Unexpec...
#
#                                        fin_situation                   csb  \
# 0  Percent Household Whose Financial Situation in...  Canada Savings Bonds
# 1  Percent Household Whose Financial Situation in...  Canada Savings Bonds
# 2  Percent Household Whose Financial Situation in...  Canada Savings Bonds
#
#    gic             real_estate mutual_funds resp rrif rrsp  stocks term  \
# 0  NaN                     NaN          NaN  NaN  NaN  NaN  Stocks  NaN
# 1  NaN  Real estate Investment          NaN  NaN  NaN  NaN  Stocks  NaN
# 2  NaN                     NaN          NaN  NaN  NaN  NaN     NaN  NaN
#
#          other
# 0  Other bonds
# 1  Other bonds
# 2          NaN

# %%
print(df.shape)
df.isnull().sum(axis = 0) #check total missing values for each column
# Out:
# (3887, 32)
# PostCode              0
# Gender                0
# Age                   0
# Demographics          0
# Ethnicity             0
# Religion              0
# Immigration           0
# Education           433
# Field.of.Study      433
# Profession          433
# Marital.Status      433
# Family.Size         433
# Dwelling            433
# Personal.Income     433
# credit_card         562
# pay_balance         562
# refuse_cc           562
# mortgage            562
# budget              562
# unexpected_500      562
# unexpected_5000     562
# fin_situation       562
# csb                2319
# gic                3398
# real_estate        2947
# mutual_funds       3746
# resp               3717
# rrif               3816
# rrsp               3669
# stocks             3276
# term               3766
# other              2765
# dtype: int64

# %%
df["Demographics"].value_counts() #explore age group
# Out:
# 65 years and over-Female    323
# 65 years and over-Male      258
# 0 to 14 years-Male          218
# 0 to 14 years-Female        215
# 30 to 34 years-Female       181
# 35 to 39 years-Female       181
# 35 to 39 years-Male         179
# 50 to 54 years-Male         178
# 45 to 49 years-Male         175
# 55 to 59 years-Male         173
# 40 to 44 years-Male         166
# 30 to 34 years-Male         160
# 40 to 44 years-Female       160
# 60 to 64 years-Male         158
# 50 to 54 years-Female       152
# 45 to 49 years-Female       151
# 55 to 59 years-Female       141
# 25 to 29 years-Female       141
# 60 to 64 years-Female       138
# 25 to 29 years-Male         131
# 20 to 24 years-Female        90
# 20 to 24 years-Male          89
# 15 to 19 years-Male          66
# 15 to 19 years-Female        63
# Name: Demographics, dtype: int64

# %%
# These demographic groups explains columns with 562 missing values
group = ["0 to 14 years-Male", "0 to 14 years-Female", "15 to 19 years-Male", "15 to 19 years-Female"]
value = 0
for groups in group:
    grp = len(df.loc[(df["Demographics"] == groups)])
    value += grp
print(value)

# These demographic groups explains columns with 433 missing values
group = ["0 to 14 years-Male", "0 to 14 years-Female"]
value = 0
for groups in group:
    grp = len(df.loc[(df["Demographics"] == groups)])
    value += grp
print(value)
# Out:
# 562
# 433

# %%
# remove demographics who are not adults (data not significant)
group = ["0 to 14 years-Male", "0 to 14 years-Female", "15 to 19 years-Male", "15 to 19 years-Female"]
for removeGroups in group:
    df = df[df.Demographics != removeGroups]

# remove the entire "Age" column (since we have demographics column)
# remove the entire "PostCode" column (we are not using postal code column at this time)
column = ['Age', 'PostCode']
for removeColumn in column:
    df = df.loc[:, df.columns != removeColumn]

# %%
data = df.copy()        #make a copy
print(data.shape)       #check for size and column
# Out:
# (3325, 30)

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# Note that we are using get_dummies since it converts strings directly to one-hot-representation all in one go.
#
# Otherwise, we would need to use label encoder to map data into integers, and then using one-hot-encoder to convert to one-hot-representation but individually.

# %%
categorical = ['Gender', 'Demographics', 'Ethnicity', 'Religion', 'Immigration', 'Education',
               'Field.of.Study', 'Profession', 'Marital.Status', 'Family.Size', 'Dwelling', 'Personal.Income',
               'credit_card', 'pay_balance', 'refuse_cc', 'mortgage', 'budget', 'unexpected_500',
               'unexpected_5000', 'fin_situation', 'csb', 'gic', 'real_estate', 'mutual_funds',
               'resp', 'rrif', 'rrsp', 'stocks', 'term', 'other']

#using get_dummies to convert data into one-hot-representations on dataset
for cat in categorical:
    dummies = pd.get_dummies(data[cat], prefix = cat, prefix_sep = "_", dtype=float) #apply get_dummies
    data = pd.concat([data, dummies], axis = 1)   #combine data and dummies (axis=1 for columns)
data.drop(categorical, axis = 1, inplace = True)  #drop original columns, inplace = True drops it permanently
data = data.reset_index(drop=True)                #re-index

# %%
data = data.copy()        #make another copy
print(data.shape)         #check for size and column
# Out:
# (3325, 156)

# %% [markdown]
# # Data Splitting

# %%
from sklearn.model_selection import train_test_split
x_train, x_test = train_test_split(data, test_size=0.2)  #keep 20% as test set
x_train = x_train.reset_index(drop=True)                 #re-index
x_test = x_test.reset_index(drop=True)  
print(x_train.shape, x_test.shape)
# Out:
# (2660, 156) (665, 156)

# %% [markdown]
# # Setting up Encoder

# %%
from keras.layers import Input, Dense             # Input is orignal layer, Dense connects other layer
from keras.models import Model
from keras import regularizers                    # Regularizer
from keras import backend as K                    # Import backend engine
from keras.callbacks import EarlyStopping         # stops model if no improvements from test data when using training data
import pickle                                     # for data storing (0 and 1)   
from sklearn.preprocessing import StandardScaler,MinMaxScaler

x_train = x_train.values                          #convert to matrix form
x_train = MinMaxScaler().fit_transform(x_train)   #convert to [0,1] scaling using MinMaxScaler
x_test = x_test.values
x_test = MinMaxScaler().fit_transform(x_test)

input_size = 156
hidden_size = 512
code_size = 3
n_epochs = 156   #number of times we pass the entire dataset through the network
batch_size = 100 #number of batches in the entire dataset

input_data = Input(shape=(input_size,))
hidden_1 = Dense(hidden_size, activation='relu')(input_data)
code = Dense(code_size, activation='relu')(hidden_1)
hidden_2 = Dense(hidden_size, activation='relu')(code)
output_data = Dense(input_size, activation='sigmoid')(hidden_2)

autoencoder = Model(input_data, output_data)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
autoencoder_history = autoencoder.fit(x_train, x_train, epochs=n_epochs, 
                                      batch_size = batch_size, validation_data=(x_test, x_test), #test data for overfitting
                                      callbacks = [EarlyStopping(monitor='loss',patience = 5)])  #callbacks if no improvements
# Out:
# Using TensorFlow backend.
# Train on 2660 samples, validate on 665 samples
# Epoch 1/156
# 2660/2660 [==============================] - 1s 223us/step - loss: 0.5010 - val_loss: 0.3283
# Epoch 2/156
# 2660/2660 [==============================] - 0s 142us/step - loss: 0.3041 - val_loss: 0.2933
# Epoch 3/156
# 2660/2660 [==============================] - 0s 144us/step - loss: 0.2878 - val_loss: 0.2845
# Epoch 4/156
# 2660/2660 [==============================] - 0s 143us/step - loss: 0.2812 - val_loss: 0.2787
# Epoch 5/156
# 2660/2660 [==============================] - 0s 142us/step - loss: 0.2677 - val_loss: 0.2570
# Epoch 6/156
# 2660/2660 [==============================] - 0s 143us/step - loss: 0.2499 - val_loss: 0.2474
# Epoch 7/156
# 2660/2660 [==============================] - 0s 143us/step - loss: 0.2420 - val_loss: 0.2432
# Epoch 8/156
# 2660/2660 [==============================] - 0s 147us/step - loss: 0.2371 - val_loss: 0.2387
# Epoch 9/156
# 2660/2660 [==============================] - 0s 145us/step - loss: 0.2327 - val_loss: 0.2363
# Epoch 10/156
# 2660/2660 [==============================] - 0s 143us/step - loss: 0.2297 - val_loss: 0.2333
# Epoch 11/156
# 2660/2660 [==============================] - 0s 143us/step - loss: 0.2270 - val_loss: 0.2316
# Epoch 12/156
# 2660/2660 [==============================] - 0s 144us/step - loss: 0.2248 - val_loss: 0.2294
# Epoch 13/156
# 2660/2660 [==============================] - 0s 144us/step - loss: 0.2226 - val_loss: 0.2273
# Epoch 14/156
# 2660/2660 [==============================] - 0s 141us/step - loss: 0.2206 - val_loss: 0.2252
# Epoch 15/156
# 2660/2660 [==============================] - 0s 141us/step - loss: 0.2186 - val_loss: 0.2248
# Epoch 16/156
# 2660/2660 [==============================] - 0s 141us/step - loss: 0.2169 - val_loss: 0.2222
# Epoch 17/156
# 2660/2660 [==============================] - 0s 140us/step - loss: 0.2150 - val_loss: 0.2207
# Epoch 18/156
# 2660/2660 [==============================] - 0s 144us/step - loss: 0.2133 - val_loss: 0.2196
# Epoch 19/156
# 2660/2660 [==============================] - 0s 142us/step - loss: 0.2119 - val_loss: 0.2182
# Epoch 20/156
# 2660/2660 [==============================] - 0s 143us/step - loss: 0.2102 - val_loss: 0.2164
# Epoch 21/156
# 2660/2660 [==============================] - 0s 142us/step - loss: 0.2083 - val_loss: 0.2161
# Epoch 22/156
# 2660/2660 [==============================] - 0s 142us/step - loss: 0.2070 - val_loss: 0.2140
# Epoch 23/156
# 2660/2660 [==============================] - 0s 143us/step - loss: 0.2054 - val_loss: 0.2128
# Epoch 24/156
# 2660/2660 [==============================] - 0s 141us/step - loss: 0.2038 - val_loss: 0.2118
# Epoch 25/156
# 2660/2660 [==============================] - 0s 142us/step - loss: 0.2027 - val_loss: 0.2108
# Epoch 26/156
# 2660/2660 [==============================] - 0s 145us/step - loss: 0.2015 - val_loss: 0.2105
# Epoch 27/156
# 2660/2660 [==============================] - 0s 139us/step - loss: 0.2003 - val_loss: 0.2098
# Epoch 28/156
# 2660/2660 [==============================] - 0s 144us/step - loss: 0.1991 - val_loss: 0.2083
# Epoch 29/156
# 2660/2660 [==============================] - 0s 145us/step - loss: 0.1979 - val_loss: 0.2074
# Epoch 30/156
# 2660/2660 [==============================] - 0s 140us/step - loss: 0.1969 - val_loss: 0.2064
# Epoch 31/156
# 2660/2660 [==============================] - 0s 142us/step - loss: 0.1958 - val_loss: 0.2061
# Epoch 32/156
# 2660/2660 [==============================] - 0s 145us/step - loss: 0.1949 - val_loss: 0.2050
# Epoch 33/156
# 2660/2660 [==============================] - 0s 143us/step - loss: 0.1939 - val_loss: 0.2051
# Epoch 34/156
# 2660/2660 [==============================] - 0s 143us/step - loss: 0.1933 - val_loss: 0.2041
# Epoch 35/156
# 2660/2660 [==============================] - 0s 142us/step - loss: 0.1922 - val_loss: 0.2034
# Epoch 36/156
# 2660/2660 [==============================] - 0s 142us/step - loss: 0.1915 - val_loss: 0.2027
# Epoch 37/156
# 2660/2660 [==============================] - 0s 141us/step - loss: 0.1905 - val_loss: 0.2024
# Epoch 38/156
# 2660/2660 [==============================] - 0s 142us/step - loss: 0.1898 - val_loss: 0.2019
# Epoch 39/156
# 2660/2660 [==============================] - 0s 144us/step - loss: 0.1890 - val_loss: 0.2013
# Epoch 40/156
# 2660/2660 [==============================] - 0s 143us/step - loss: 0.1885 - val_loss: 0.2013
# Epoch 41/156
# 2660/2660 [==============================] - 0s 143us/step - loss: 0.1878 - val_loss: 0.2008
# Epoch 42/156
# 2660/2660 [==============================] - 0s 142us/step - loss: 0.1871 - val_loss: 0.2008
# Epoch 43/156
# 2660/2660 [==============================] - 0s 141us/step - loss: 0.1864 - val_loss: 0.2000
# Epoch 44/156
# 2660/2660 [==============================] - 0s 143us/step - loss: 0.1858 - val_loss: 0.1993
# Epoch 45/156
# 2660/2660 [==============================] - 0s 141us/step - loss: 0.1849 - val_loss: 0.1995
# Epoch 46/156
# 2660/2660 [==============================] - 0s 140us/step - loss: 0.1844 - val_loss: 0.1985
# Epoch 47/156
# 2660/2660 [==============================] - 0s 141us/step - loss: 0.1840 - val_loss: 0.1983
# Epoch 48/156
# 2660/2660 [==============================] - 0s 143us/step - loss: 0.1830 - val_loss: 0.1988
# Epoch 49/156
# 2660/2660 [==============================] - 0s 145us/step - loss: 0.1826 - val_loss: 0.1976
# Epoch 50/156
# 2660/2660 [==============================] - 0s 142us/step - loss: 0.1819 - val_loss: 0.1979
# Epoch 51/156
# 2660/2660 [==============================] - 0s 141us/step - loss: 0.1814 - val_loss: 0.1971
# Epoch 52/156
# 2660/2660 [==============================] - 0s 147us/step - loss: 0.1805 - val_loss: 0.1965
# Epoch 53/156
# 2660/2660 [==============================] - 0s 143us/step - loss: 0.1804 - val_loss: 0.1965
# Epoch 54/156
# 2660/2660 [==============================] - 0s 142us/step - loss: 0.1797 - val_loss: 0.1967
# Epoch 55/156
# 2660/2660 [==============================] - 0s 155us/step - loss: 0.1790 - val_loss: 0.1955
# Epoch 56/156
# 2660/2660 [==============================] - 0s 142us/step - loss: 0.1782 - val_loss: 0.1957
# Epoch 57/156
# 2660/2660 [==============================] - 0s 142us/step - loss: 0.1779 - val_loss: 0.1952
# Epoch 58/156
# 2660/2660 [==============================] - 0s 142us/step - loss: 0.1772 - val_loss: 0.1946
# Epoch 59/156
# 2660/2660 [==============================] - 0s 143us/step - loss: 0.1766 - val_loss: 0.1955
# Epoch 60/156
# 2660/2660 [==============================] - 0s 142us/step - loss: 0.1760 - val_loss: 0.1946
# Epoch 61/156
# 2660/2660 [==============================] - 0s 144us/step - loss: 0.1754 - val_loss: 0.1947
# Epoch 62/156
# 2660/2660 [==============================] - 0s 142us/step - loss: 0.1750 - val_loss: 0.1938
# Epoch 63/156
# 2660/2660 [==============================] - 0s 142us/step - loss: 0.1746 - val_loss: 0.1939
# Epoch 64/156
# 2660/2660 [==============================] - 0s 142us/step - loss: 0.1742 - val_loss: 0.1934
# Epoch 65/156
# 2660/2660 [==============================] - 0s 143us/step - loss: 0.1735 - val_loss: 0.1935
# Epoch 66/156
# 2660/2660 [==============================] - 0s 143us/step - loss: 0.1728 - val_loss: 0.1937
# Epoch 67/156
# 2660/2660 [==============================] - 0s 140us/step - loss: 0.1727 - val_loss: 0.1927
# Epoch 68/156
# 2660/2660 [==============================] - 0s 141us/step - loss: 0.1722 - val_loss: 0.1931
# Epoch 69/156
# 2660/2660 [==============================] - 0s 144us/step - loss: 0.1719 - val_loss: 0.1922
# Epoch 70/156
# 2660/2660 [==============================] - 0s 143us/step - loss: 0.1712 - val_loss: 0.1922
# Epoch 71/156
# 2660/2660 [==============================] - 0s 144us/step - loss: 0.1708 - val_loss: 0.1918
# Epoch 72/156
# 2660/2660 [==============================] - 0s 145us/step - loss: 0.1703 - val_loss: 0.1918
# Epoch 73/156
# 2660/2660 [==============================] - 0s 141us/step - loss: 0.1700 - val_loss: 0.1924
# Epoch 74/156
# 2660/2660 [==============================] - 0s 144us/step - loss: 0.1699 - val_loss: 0.1927
# Epoch 75/156
# 2660/2660 [==============================] - 0s 144us/step - loss: 0.1693 - val_loss: 0.1918
# Epoch 76/156
# 2660/2660 [==============================] - 0s 142us/step - loss: 0.1689 - val_loss: 0.1917
# Epoch 77/156
# 2660/2660 [==============================] - 0s 143us/step - loss: 0.1684 - val_loss: 0.1917
# Epoch 78/156
# 2660/2660 [==============================] - 0s 141us/step - loss: 0.1684 - val_loss: 0.1912
# Epoch 79/156
# 2660/2660 [==============================] - 0s 142us/step - loss: 0.1681 - val_loss: 0.1915
# Epoch 80/156
# 2660/2660 [==============================] - 0s 141us/step - loss: 0.1677 - val_loss: 0.1912
# Epoch 81/156
# 2660/2660 [==============================] - 0s 141us/step - loss: 0.1670 - val_loss: 0.1912
# Epoch 82/156
# 2660/2660 [==============================] - 0s 142us/step - loss: 0.1670 - val_loss: 0.1917
# Epoch 83/156
# 2660/2660 [==============================] - 0s 143us/step - loss: 0.1667 - val_loss: 0.1905
# Epoch 84/156
# 2660/2660 [==============================] - 0s 143us/step - loss: 0.
156
# 2660/2660 [==============================] - 0s 142us/step - loss: 0.1523 - val_loss: 0.1907
# Epoch 144/156
# 2660/2660 [==============================] - 0s 144us/step - loss: 0.1521 - val_loss: 0.1905
# Epoch 145/156
# 2660/2660 [==============================] - 0s 145us/step - loss: 0.1515 - val_loss: 0.1913
# Epoch 146/156
# 2660/2660 [==============================] - 0s 144us/step - loss: 0.1513 - val_loss: 0.1924
# Epoch 147/156
# 2660/2660 [==============================] - 0s 143us/step - loss: 0.1514 - val_loss: 0.1919
# Epoch 148/156
# 2660/2660 [==============================] - 0s 141us/step - loss: 0.1511 - val_loss: 0.1922
# Epoch 149/156
# 2660/2660 [==============================] - 0s 141us/step - loss: 0.1507 - val_loss: 0.1925
# Epoch 150/156
# 2660/2660 [==============================] - 0s 143us/step - loss: 0.1509 - val_loss: 0.1910
# Epoch 151/156
# 2660/2660 [==============================] - 0s 141us/step - loss: 0.1510 - val_loss: 0.1927
# Epoch 152/156
# 2660/2660 [==============================] - 0s 144us/step - loss: 0.1505 - val_loss: 0.1917
# Epoch 153/156
# 2660/2660 [==============================] - 0s 144us/step - loss: 0.1502 - val_loss: 0.1925
# Epoch 154/156
# 2660/2660 [==============================] - 0s 143us/step - loss: 0.1501 - val_loss: 0.1929
# Epoch 155/156
# 2660/2660 [==============================] - 0s 141us/step - loss: 0.1503 - val_loss: 0.1920
# Epoch 156/156
# 2660/2660 [==============================] - 0s 144us/step - loss: 0.1497 - val_loss: 0.1919

# %%
plt.plot(autoencoder_history.history['loss'])
plt.plot(autoencoder_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show();

# %% [markdown]
# # Clustering dimension reduced data in 3D (autoencoder)

# %%
#Get code layer
get_3rd_layer_output = K.function([autoencoder.layers[0].input],[autoencoder.layers[2].output]) #first and third layer
layer_output = get_3rd_layer_output([x_train])[0]
layer_output
# Out:
# array([[11.254238 , 46.994553 , 13.683618 ],
#        [22.084898 , 14.059239 , 12.076016 ],
#        [ 3.8224397,  8.0693035, 38.0813   ],
#        ...,
#        [33.30512  , 40.069656 , 36.939114 ],
#        [15.787674 , 24.815016 , 56.593452 ],
#        [22.903963 , 16.900923 , 12.316034 ]], dtype=float32)

# %%
#Visualization on clusters
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(1, figsize=(15, 10))
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)
ax.scatter(layer_output[:,0], layer_output[:,1], layer_output[:,2],c=layer_output[:,0])
ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])
ax.set_xlabel('Seg 1')
ax.set_ylabel('Seg 2')
ax.set_zlabel('Seg 3')
ax.set_title("3D Dimension Reduced Data Clustering (Autoencoder)")
ax.dist = 9

# %% [markdown]
# # Clustering dimension reduced data in 2D (autoencoder)

# %%
data = data.copy()        #make another copy

#Data splitting
from sklearn.model_selection import train_test_split
x_train, x_test = train_test_split(data, test_size=0.2)  #keep 20% as test set
x_train = x_train.reset_index(drop=True)                 #re-index
x_test = x_test.reset_index(drop=True)  

#Setting up Encoder
from keras.layers import Input, Dense             # Input is orignal layer, Dense connects other layer
from keras.models import Model
from keras import regularizers                    # Regularizer
from keras import backend as K                    # Import backend engine
from keras.callbacks import EarlyStopping         # stops model if no improvements from test data when using training data
import pickle                                     # for data storing (0 and 1)   
from sklearn.preprocessing import StandardScaler,MinMaxScaler

x_train = x_train.values                          #convert to matrix form
x_train = MinMaxScaler().fit_transform(x_train)   #convert to [0,1] scaling using MinMaxScaler
x_test = x_test.values
x_test = MinMaxScaler().fit_transform(x_test)

input_size = 156
hidden_size = 512
code_size = 2
n_epochs = 156   #number of times we pass the entire dataset through the network
batch_size = 100 #number of batches in the entire dataset

input_data = Input(shape=(input_size,))
hidden_1 = Dense(hidden_size, activation='relu')(input_data)
code = Dense(code_size, activation='relu')(hidden_1)
hidden_2 = Dense(hidden_size, activation='relu')(code)
output_data = Dense(input_size, activation='sigmoid')(hidden_2)

autoencoder = Model(input_data, output_data)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
autoenco
156
# 2660/2660 [==============================] - 0s 145us/step - loss: 0.2056 - val_loss: 0.2233
# Epoch 115/156
# 2660/2660 [==============================] - 0s 140us/step - loss: 0.2054 - val_loss: 0.2228
# Epoch 116/156
# 2660/2660 [==============================] - 0s 144us/step - loss: 0.2052 - val_loss: 0.2231
# Epoch 117/156
# 2660/2660 [==============================] - 0s 141us/step - loss: 0.2050 - val_loss: 0.2232
# Epoch 118/156
# 2660/2660 [==============================] - 0s 142us/step - loss: 0.2049 - val_loss: 0.2230
# Epoch 119/156
# 2660/2660 [==============================] - 0s 143us/step - loss: 0.2045 - val_loss: 0.2227
# Epoch 120/156
# 2660/2660 [==============================] - 0s 143us/step - loss: 0.2043 - val_loss: 0.2230
# Epoch 121/156
# 2660/2660 [==============================] - 0s 142us/step - loss: 0.2042 - val_loss: 0.2235
# Epoch 122/156
# 2660/2660 [==============================] - 0s 142us/step - loss: 0.2042 - val_loss: 0.2229
# Epoch 123/156
# 2660/2660 [==============================] - 0s 142us/step - loss: 0.2039 - val_loss: 0.2229
# Epoch 124/156
# 2660/2660 [==============================] - 0s 143us/step - loss: 0.2038 - val_loss: 0.2232
# Epoch 125/156
# 2660/2660 [==============================] - 0s 145us/step - loss: 0.2036 - val_loss: 0.2230
# Epoch 126/156
# 2660/2660 [==============================] - 0s 142us/step - loss: 0.2032 - val_loss: 0.2231
# Epoch 127/156
# 2660/2660 [==============================] - 0s 142us/step - loss: 0.2033 - val_loss: 0.2229
# Epoch 128/156
# 2660/2660 [==============================] - 0s 143us/step - loss: 0.2030 - val_loss: 0.2229
# Epoch 129/156
# 2660/2660 [==============================] - 0s 147us/step - loss: 0.2030 - val_loss: 0.2231
# Epoch 130/156
# 2660/2660 [==============================] - 0s 141us/step - loss: 0.2029 - val_loss: 0.2225
# Epoch 131/156
# 2660/2660 [==============================] - 0s 145us/step - loss: 0.2024 - val_loss: 0.2228
# Epoch 132/156
# 2660/2660 [==============================] - 0s 144us/step - loss: 0.2023 - val_loss: 0.2232
# Epoch 133/156
# 2660/2660 [==============================] - 0s 145us/step - loss: 0.2022 - val_loss: 0.2225
# Epoch 134/156
# 2660/2660 [==============================] - 0s 147us/step - loss: 0.2017 - val_loss: 0.2233
# Epoch 135/156
# 2660/2660 [==============================] - 0s 145us/step - loss: 0.2019 - val_loss: 0.2231
# Epoch 136/156
# 2660/2660 [==============================] - 0s 141us/step - loss: 0.2018 - val_loss: 0.2234
# Epoch 137/156
# 2660/2660 [==============================] - 0s 141us/step - loss: 0.2014 - val_loss: 0.2224
# Epoch 138/156
# 2660/2660 [==============================] - 0s 142us/step - loss: 0.2012 - val_loss: 0.2234
# Epoch 139/156
# 2660/2660 [==============================] - 0s 144us/step - loss: 0.2014 - val_loss: 0.2236
# Epoch 140/156
# 2660/2660 [==============================] - 0s 143us/step - loss: 0.2012 - val_loss: 0.2230
# Epoch 141/156
# 2660/2660 [==============================] - 0s 141us/step - loss: 0.2011 - val_loss: 0.2231
# Epoch 142/156
# 2660/2660 [==============================] - 0s 141us/step - loss: 0.2007 - val_loss: 0.2226
# Epoch 143/156
# 2660/2660 [==============================] - 0s 142us/step - loss: 0.2009 - val_loss: 0.2229
# Epoch 144/156
# 2660/2660 [==============================] - 0s 140us/step - loss: 0.2004 - val_loss: 0.2228
# Epoch 145/156
# 2660/2660 [==============================] - 0s 142us/step - loss: 0.2002 - val_loss: 0.2227
# Epoch 146/156
# 2660/2660 [==============================] - 0s 143us/step - loss: 0.2001 - val_loss: 0.2228
# Epoch 147/156
# 2660/2660 [==============================] - 0s 143us/step - loss: 0.1999 - val_loss: 0.2226
# Epoch 148/156
# 2660/2660 [==============================] - 0s 143us/step - loss: 0.2000 - val_loss: 0.2228
# Epoch 149/156
# 2660/2660 [==============================] - 0s 143us/step - loss: 0.1998 - val_loss: 0.2228
# Epoch 150/156
# 2660/2660 [==============================] - 0s 140us/step - loss: 0.1995 - val_loss: 0.2231
# Epoch 151/156
# 2660/2660 [==============================] - 0s 145us/step - loss: 0.1995 - val_loss: 0.2230
# Epoch 152/156
# 2660/2660 [==============================] - 0s 141us/step - loss: 0.1994 - val_loss: 0.2238
# Epoch 153/156
# 2660/2660 [==============================] - 0s 141us/step - loss: 0.1993 - val_loss: 0.2233
# Epoch 154/156
# 2660/2660 [==============================] - 0s 143us/step - loss: 0.1989 - val_loss: 0.2224
# Epoch 155/156
# 2660/2660 [==============================] - 0s 143us/step - loss: 0.1989 - val_loss: 0.2236
# Epoch 156/156
# 2660/2660 [==============================] - 0s 142us/step - loss: 0.1989 - val_loss: 0.2232

# %%
plt.plot(autoencoder_history.history['loss'])
plt.plot(autoencoder_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show();

# %%
#Get code layer
get_3rd_layer_output = K.function([autoencoder.layers[0].input],[autoencoder.layers[2].output]) #first and third layer
layer_output = get_3rd_layer_output([x_train])[0]

#Visualization on clusters
fig = plt.figure(1, figsize=(15, 10))
plt.scatter(layer_output[:,0], layer_output[:,1], c=layer_output[:,0])
plt.xlabel("Seg 1")
plt.ylabel("Seg 2")
plt.title("2D Dimension Reduced Data Clustering (Autoencoder)")
# Out:
# Text(0.5, 1.0, '2D Dimension Reduced Data Clustering (Autoencoder)')
